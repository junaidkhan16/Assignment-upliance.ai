# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel(r"C:\Users\Admin\Downloads\Assignment.xlsx", sheet_name=None)

# %%
data
# Out:
# {'UserDetails.csv':   User ID      User Name  Age       Location Registration Date         Phone  \
#  0    U001  Alice Johnson   28       New York        2023-01-15  123-456-7890
#  1    U002      Bob Smith   35    Los Angeles        2023-02-20  987-654-3210
#  2    U003    Charlie Lee   42        Chicago        2023-03-10  555-123-4567
#  3    U004    David Brown   27  San Francisco        2023-04-05  444-333-2222
#  4    U005     Emma White   30        Seattle        2023-05-22  777-888-9999
#  5    U006    Frank Green   25         Austin        2023-06-15  888-777-6666
#  6    U007     Grace King   38         Boston        2023-07-02  999-888-7777
#  7    U008      Henry Lee   31          Miami        2023-08-11  101-202-3030
#  8    U009    Irene Moore   33         Dallas        2023-09-01  202-303-4040
#  9    U010     Jack White   29        Phoenix        2023-10-10  303-404-5050
#
#                 Email Favorite Meal  Total Orders
#  0    alice@email.com        Dinner            12
#  1      bob@email.com         Lunch             8
#  2  charlie@email.com     Breakfast            15
#  3    david@email.com        Dinner            10
#  4     emma@email.com         Lunch             9
#  5    frank@email.com        Dinner             7
#  6    grace@email.com     Breakfast            14
#  7    henry@email.com        Dinner             5
#  8    irene@email.com         Lunch             6
#  9     jack@email.com        Dinner             8  ,
#  'CookingSessions.csv':    Session ID User ID        Dish Name  Meal Type       Session Start  \
#  0        S001    U001        Spaghetti     Dinner 2024-12-01 19:00:00
#  1        S002    U002     Caesar Salad      Lunch 2024-12-01 12:00:00
#  2        S003    U003  Grilled Chicken     Dinner 2024-12-02 19:30:00
#  3        S004    U001         Pancakes  Breakfast 2024-12-02 07:30:00
#  4        S005    U004     Caesar Salad      Lunch 2024-12-03 13:00:00
#  5        S006    U002        Spaghetti     Dinner 2024-12-03 18:30:00
#  6        S007    U005  Grilled Chicken     Dinner 2024-12-04 18:00:00
#  7        S008    U003    Veggie Burger      Lunch 2024-12-04 13:30:00
#  8        S009    U001  Grilled Chicken     Dinner 2024-12-05 19:00:00
#  9        S010    U002          Oatmeal  Breakfast 2024-12-05 07:00:00
#  10       S011    U003         Pancakes  Breakfast 2024-12-06 08:00:00
#  11       S012    U004        Spaghetti     Dinner 2024-12-06 19:00:00
#  12       S013    U005     Caesar Salad      Lunch 2024-12-07 12:30:00
#  13       S014    U006  Grilled Chicken     Dinner 2024-12-07 18:00:00
#  14       S015    U007        Spaghetti     Dinner 2024-12-08 19:30:00
#  15       S016    U008    Veggie Burger      Lunch 2024-12-08 13:30:00
#
#             Session End  Duration (mins)  Session Rating
#  0  2024-12-01 19:30:00               30             4.5
#  1  2024-12-01 12:20:00               20             4.0
#  2  2024-12-02 20:10:00               40             4.8
#  3  2024-12-02 08:00:00               30             4.2
#  4  2024-12-03 13:15:00               15             4.7
#  5  2024-12-03 19:00:00               30             4.3
#  6  2024-12-04 18:45:00               45             4.6
#  7  2024-12-04 13:50:00               20             4.4
#  8  2024-12-05 19:40:00               40             4.9
#  9  2024-12-05 07:10:00               10             4.1
#  10 2024-12-06 08:30:00               30             4.6
#  11 2024-12-06 19:40:00               40             4.7
#  12 2024-12-07 13:00:00               30             4.4
#  13 2024-12-07 18:45:00               45             4.8
#  14 2024-12-08 20:10:00               40             5.0
#  15 2024-12-08 13:50:00               20             4.3  ,
#  'OrderDetails.csv':     Order ID User ID Order Date  Meal Type        Dish Name Order Status  \
#  0       1001    U001 2024-12-01     Dinner        Spaghetti    Completed
#  1       1002    U002 2024-12-01      Lunch     Caesar Salad    Completed
#  2       1003    U003 2024-12-02     Dinner  Grilled Chicken     Canceled
#  3       1004    U001 2024-12-02  Breakfast         Pancakes    Completed
#  4       1005    U004 2024-12-03      Lunch     Caesar Salad    Completed
#  5       1006    U002 2024-12-03     Dinner        Spaghetti    Completed
#  6       1007    U005 2024-12-04     Dinner  Grilled Chicken    Completed
#  7       1008    U003 2024-12-04      Lunch    Veggie Burger     Canceled
#  8       1009    U001 2024-12-05     Dinner  Grilled Chicken    Completed
#  9       1010    U002 2024-12-05  Breakfast          Oatmeal    Completed
#  10      1011    U003 2024-12-06  Breakfast         Pancakes    Completed
#  11      1012    U004 2024-12-06     Dinner        Spaghetti    Completed
#  12      1013    U005 2024-12-07      Lunch     Caesar Salad    Completed
#  13      1014    U006 2024-12-07     Dinner  Grilled Chicken    Completed
#  14      1015    U007 2024-12-08     Dinner        Spaghetti    Completed
#  15      1016    U008 2024-12-08      Lunch    Veggie Burger    Completed
#
#      Amount (USD) Time of Day  Rating Session ID
#  0           15.0       Night     5.0       S001
#  1           10.0         Day     4.0       S002
#  2           12.5       Night     NaN       S003
#  3            8.0     Morning     4.0       S004
#  4            9.0         Day     4.0       S005
#  5           14.0       Night     4.0       S006
#  6           13.5       Night     4.0       S007
#  7           11.0         Day     NaN       S008
#  8           12.0       Night     5.0       S009
#  9            7.0     Morning     4.0       S010
#  10           8.5     Morning     4.0       S011
#  11          12.5       Night     4.0       S012
#  12           9.0         Day     4.0       S013
#  13          13.0       Night     5.0       S014
#  14          14.0       Night     5.0       S015
#  15          11.0         Day     4.0       S016  }

# %%
UserDetails = data['UserDetails.csv']
CookingSessions = data['CookingSessions.csv']
OrderDetails = data['OrderDetails.csv']

# %%
UserDetails
# Out:
#   User ID      User Name  Age       Location Registration Date         Phone  \
# 0    U001  Alice Johnson   28       New York        2023-01-15  123-456-7890
# 1    U002      Bob Smith   35    Los Angeles        2023-02-20  987-654-3210
# 2    U003    Charlie Lee   42        Chicago        2023-03-10  555-123-4567
# 3    U004    David Brown   27  San Francisco        2023-04-05  444-333-2222
# 4    U005     Emma White   30        Seattle        2023-05-22  777-888-9999
# 5    U006    Frank Green   25         Austin        2023-06-15  888-777-6666
# 6    U007     Grace King   38         Boston        2023-07-02  999-888-7777
# 7    U008      Henry Lee   31          Miami        2023-08-11  101-202-3030
# 8    U009    Irene Moore   33         Dallas        2023-09-01  202-303-4040
# 9    U010     Jack White   29        Phoenix        2023-10-10  303-404-5050
#
#                Email Favorite Meal  Total Orders
# 0    alice@email.com        Dinner            12
# 1      bob@email.com         Lunch             8
# 2  charlie@email.com     Breakfast            15
# 3    david@email.com        Dinner            10
# 4     emma@email.com         Lunch             9
# 5    frank@email.com        Dinner             7
# 6    grace@email.com     Breakfast            14
# 7    henry@email.com        Dinner             5
# 8    irene@email.com         Lunch             6
# 9     jack@email.com        Dinner             8

# %%
CookingSessions
# Out:
#    Session ID User ID        Dish Name  Meal Type       Session Start  \
# 0        S001    U001        Spaghetti     Dinner 2024-12-01 19:00:00
# 1        S002    U002     Caesar Salad      Lunch 2024-12-01 12:00:00
# 2        S003    U003  Grilled Chicken     Dinner 2024-12-02 19:30:00
# 3        S004    U001         Pancakes  Breakfast 2024-12-02 07:30:00
# 4        S005    U004     Caesar Salad      Lunch 2024-12-03 13:00:00
# 5        S006    U002        Spaghetti     Dinner 2024-12-03 18:30:00
# 6        S007    U005  Grilled Chicken     Dinner 2024-12-04 18:00:00
# 7        S008    U003    Veggie Burger      Lunch 2024-12-04 13:30:00
# 8        S009    U001  Grilled Chicken     Dinner 2024-12-05 19:00:00
# 9        S010    U002          Oatmeal  Breakfast 2024-12-05 07:00:00
# 10       S011    U003         Pancakes  Breakfast 2024-12-06 08:00:00
# 11       S012    U004        Spaghetti     Dinner 2024-12-06 19:00:00
# 12       S013    U005     Caesar Salad      Lunch 2024-12-07 12:30:00
# 13       S014    U006  Grilled Chicken     Dinner 2024-12-07 18:00:00
# 14       S015    U007        Spaghetti     Dinner 2024-12-08 19:30:00
# 15       S016    U008    Veggie Burger      Lunch 2024-12-08 13:30:00
#
#            Session End  Duration (mins)  Session Rating
# 0  2024-12-01 19:30:00               30             4.5
# 1  2024-12-01 12:20:00               20             4.0
# 2  2024-12-02 20:10:00               40             4.8
# 3  2024-12-02 08:00:00               30             4.2
# 4  2024-12-03 13:15:00               15             4.7
# 5  2024-12-03 19:00:00               30             4.3
# 6  2024-12-04 18:45:00               45             4.6
# 7  2024-12-04 13:50:00               20             4.4
# 8  2024-12-05 19:40:00               40             4.9
# 9  2024-12-05 07:10:00               10             4.1
# 10 2024-12-06 08:30:00               30             4.6
# 11 2024-12-06 19:40:00               40             4.7
# 12 2024-12-07 13:00:00               30             4.4
# 13 2024-12-07 18:45:00               45             4.8
# 14 2024-12-08 20:10:00               40             5.0
# 15 2024-12-08 13:50:00               20             4.3

# %%
OrderDetails
# Out:
#     Order ID User ID Order Date  Meal Type        Dish Name Order Status  \
# 0       1001    U001 2024-12-01     Dinner        Spaghetti    Completed
# 1       1002    U002 2024-12-01      Lunch     Caesar Salad    Completed
# 2       1003    U003 2024-12-02     Dinner  Grilled Chicken     Canceled
# 3       1004    U001 2024-12-02  Breakfast         Pancakes    Completed
# 4       1005    U004 2024-12-03      Lunch     Caesar Salad    Completed
# 5       1006    U002 2024-12-03     Dinner        Spaghetti    Completed
# 6       1007    U005 2024-12-04     Dinner  Grilled Chicken    Completed
# 7       1008    U003 2024-12-04      Lunch    Veggie Burger     Canceled
# 8       1009    U001 2024-12-05     Dinner  Grilled Chicken    Completed
# 9       1010    U002 2024-12-05  Breakfast          Oatmeal    Completed
# 10      1011    U003 2024-12-06  Breakfast         Pancakes    Completed
# 11      1012    U004 2024-12-06     Dinner        Spaghetti    Completed
# 12      1013    U005 2024-12-07      Lunch     Caesar Salad    Completed
# 13      1014    U006 2024-12-07     Dinner  Grilled Chicken    Completed
# 14      1015    U007 2024-12-08     Dinner        Spaghetti    Completed
# 15      1016    U008 2024-12-08      Lunch    Veggie Burger    Completed
#
#     Amount (USD) Time of Day  Rating Session ID
# 0           15.0       Night     5.0       S001
# 1           10.0         Day     4.0       S002
# 2           12.5       Night     NaN       S003
# 3            8.0     Morning     4.0       S004
# 4            9.0         Day     4.0       S005
# 5           14.0       Night     4.0       S006
# 6           13.5       Night     4.0       S007
# 7           11.0         Day     NaN       S008
# 8           12.0       Night     5.0       S009
# 9            7.0     Morning     4.0       S010
# 10           8.5     Morning     4.0       S011
# 11          12.5       Night     4.0       S012
# 12           9.0         Day     4.0       S013
# 13          13.0       Night     5.0       S014
# 14          14.0       Night     5.0       S015
# 15          11.0         Day     4.0       S016

# %%
#Removing Canceled Orders
df_clean_orders = OrderDetails[OrderDetails['Order Status'] != 'Canceled']

# %%
df_clean_orders
# Out:
#     Order ID User ID Order Date  Meal Type        Dish Name Order Status  \
# 0       1001    U001 2024-12-01     Dinner        Spaghetti    Completed
# 1       1002    U002 2024-12-01      Lunch     Caesar Salad    Completed
# 3       1004    U001 2024-12-02  Breakfast         Pancakes    Completed
# 4       1005    U004 2024-12-03      Lunch     Caesar Salad    Completed
# 5       1006    U002 2024-12-03     Dinner        Spaghetti    Completed
# 6       1007    U005 2024-12-04     Dinner  Grilled Chicken    Completed
# 8       1009    U001 2024-12-05     Dinner  Grilled Chicken    Completed
# 9       1010    U002 2024-12-05  Breakfast          Oatmeal    Completed
# 10      1011    U003 2024-12-06  Breakfast         Pancakes    Completed
# 11      1012    U004 2024-12-06     Dinner        Spaghetti    Completed
# 12      1013    U005 2024-12-07      Lunch     Caesar Salad    Completed
# 13      1014    U006 2024-12-07     Dinner  Grilled Chicken    Completed
# 14      1015    U007 2024-12-08     Dinner        Spaghetti    Completed
# 15      1016    U008 2024-12-08      Lunch    Veggie Burger    Completed
#
#     Amount (USD) Time of Day  Rating Session ID
# 0           15.0       Night     5.0       S001
# 1           10.0         Day     4.0       S002
# 3            8.0     Morning     4.0       S004
# 4            9.0         Day     4.0       S005
# 5           14.0       Night     4.0       S006
# 6           13.5       Night     4.0       S007
# 8           12.0       Night     5.0       S009
# 9            7.0     Morning     4.0       S010
# 10           8.5     Morning     4.0       S011
# 11          12.5       Night     4.0       S012
# 12           9.0         Day     4.0       S013
# 13          13.0       Night     5.0       S014
# 14          14.0       Night     5.0       S015
# 15          11.0         Day     4.0       S016

# %%
# Merging DataFrames
df_merged = pd.merge(df_clean_orders, CookingSessions,  on=['Session ID', 'User ID'], how='inner')
df_final = pd.merge(UserDetails,df_merged, on='User ID', how='inner')

# %%
df_final
# Out:
#    User ID      User Name  Age       Location Registration Date         Phone  \
# 0     U001  Alice Johnson   28       New York        2023-01-15  123-456-7890
# 1     U001  Alice Johnson   28       New York        2023-01-15  123-456-7890
# 2     U001  Alice Johnson   28       New York        2023-01-15  123-456-7890
# 3     U002      Bob Smith   35    Los Angeles        2023-02-20  987-654-3210
# 4     U002      Bob Smith   35    Los Angeles        2023-02-20  987-654-3210
# 5     U002      Bob Smith   35    Los Angeles        2023-02-20  987-654-3210
# 6     U003    Charlie Lee   42        Chicago        2023-03-10  555-123-4567
# 7     U004    David Brown   27  San Francisco        2023-04-05  444-333-2222
# 8     U004    David Brown   27  San Francisco        2023-04-05  444-333-2222
# 9     U005     Emma White   30        Seattle        2023-05-22  777-888-9999
# 10    U005     Emma White   30        Seattle        2023-05-22  777-888-9999
# 11    U006    Frank Green   25         Austin        2023-06-15  888-777-6666
# 12    U007     Grace King   38         Boston        2023-07-02  999-888-7777
# 13    U008      Henry Lee   31          Miami        2023-08-11  101-202-3030
#
#                 Email Favorite Meal  Total Orders  Order ID  ... Amount (USD)  \
# 0     alice@email.com        Dinner            12      1001  ...         15.0
# 1     alice@email.com        Dinner            12      1004  ...          8.0
# 2     alice@email.com        Dinner            12      1009  ...         12.0
# 3       bob@email.com         Lunch             8      1002  ...         10.0
# 4       bob@email.com         Lunch             8      1006  ...         14.0
# 5       bob@email.com         Lunch             8      1010  ...          7.0
# 6   charlie@email.com     Breakfast            15      1011  ...          8.5
# 7     david@email.com        Dinner            10      1005  ...          9.0
# 8     david@email.com        Dinner            10      1012  ...         12.5
# 9      emma@email.com         Lunch             9      1007  ...         13.5
# 10     emma@email.com         Lunch             9      1013  ...          9.0
# 11    frank@email.com        Dinner             7      1014  ...         13.0
# 12    grace@email.com     Breakfast            14      1015  ...         14.0
# 13    henry@email.com        Dinner             5      1016  ...         11.0
#
#    Time of Day Rating Session ID      Dish Name_y Meal Type_y  \
# 0        Night    5.0       S001        Spaghetti      Dinner
# 1      Morning    4.0       S004         Pancakes   Breakfast
# 2        Night    5.0       S009  Grilled Chicken      Dinner
# 3          Day    4.0       S002     Caesar Salad       Lunch
# 4        Night    4.0       S006        Spaghetti      Dinner
# 5      Morning    4.0       S010          Oatmeal   Breakfast
# 6      Morning    4.0       S011         Pancakes   Breakfast
# 7          Day    4.0       S005     Caesar Salad       Lunch
# 8        Night    4.0       S012        Spaghetti      Dinner
# 9        Night    4.0       S007  Grilled Chicken      Dinner
# 10         Day    4.0       S013     Caesar Salad       Lunch
# 11       Night    5.0       S014  Grilled Chicken      Dinner
# 12       Night    5.0       S015        Spaghetti      Dinner
# 13         Day    4.0       S016    Veggie Burger       Lunch
#
#          Session Start         Session End Duration (mins) Session Rating
# 0  2024-12-01 19:00:00 2024-12-01 19:30:00              30            4.5
# 1  2024-12-02 07:30:00 2024-12-02 08:00:00              30            4.2
# 2  2024-12-05 19:00:00 2024-12-05 19:40:00              40            4.9
# 3  2024-12-01 12:00:00 2024-12-01 12:20:00              20            4.0
# 4  2024-12-03 18:30:00 2024-12-03 19:00:00              30            4.3
# 5  2024-12-05 07:00:00 2024-12-05 07:10:00              10            4.1
# 6  2024-12-06 08:00:00 2024-12-06 08:30:00              30            4.6
# 7  2024-12-03 13:00:00 2024-12-03 13:15:00              15            4.7
# 8  2024-12-06 19:00:00 2024-12-06 19:40:00              40            4.7
# 9  2024-12-04 18:00:00 2024-12-04 18:45:00              45            4.6
# 10 2024-12-07 12:30:00 2024-12-07 13:00:00              30            4.4
# 11 2024-12-07 18:00:00 2024-12-07 18:45:00              45            4.8
# 12 2024-12-08 19:30:00 2024-12-08 20:10:00              40            5.0
# 13 2024-12-08 13:30:00 2024-12-08 13:50:00              20            4.3
#
# [14 rows x 24 columns]

# %%
# Counting completed orders per dish
popular_dishes = df_final.groupby('Dish Name_x').agg(
    Total_Orders=('Order ID', 'count'),
    Average_Rating=('Rating', 'mean')
).reset_index().sort_values(by='Total_Orders', ascending=False)

# %%
popular_dishes
# Out:
#        Dish Name_x  Total_Orders  Average_Rating
# 4        Spaghetti             4        4.500000
# 0     Caesar Salad             3        4.000000
# 1  Grilled Chicken             3        4.666667
# 3         Pancakes             2        4.000000
# 2          Oatmeal             1        4.000000
# 5    Veggie Burger             1        4.000000

# %%
# Popular Dishes
plt.figure(figsize=(10, 6))
sns.barplot(data=popular_dishes.head(5), x='Dish Name_x', y='Total_Orders', palette='coolwarm')
plt.title('Top 5 Popular Dishes by Number of Orders')
plt.xlabel('Dish Name')
plt.ylabel('Total Orders')
plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Average order amount by location
location_order_amount = df_final.groupby('Location').agg(
    Average_Amount=('Amount (USD)', 'mean')
).reset_index().sort_values(by='Average_Amount', ascending=False)

# %%
location_order_amount
# Out:
#         Location  Average_Amount
# 1         Boston       14.000000
# 0         Austin       13.000000
# 5       New York       11.666667
# 7        Seattle       11.250000
# 4          Miami       11.000000
# 6  San Francisco       10.750000
# 3    Los Angeles       10.333333
# 2        Chicago        8.500000

# %%
# Average Order Amount by Location
plt.figure(figsize=(12, 6))
sns.barplot(data=location_order_amount, x='Location', y='Average_Amount', palette='viridis')
plt.title('Average Order Amount by Location')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Most Frequent Meal Types per User
user_meal_type = df_final.groupby(['User ID', 'Meal Type_x']).size().reset_index(name='Order Count')
user_meal_type
# Out:
#    User ID Meal Type_x  Order Count
# 0     U001   Breakfast            1
# 1     U001      Dinner            2
# 2     U002   Breakfast            1
# 3     U002      Dinner            1
# 4     U002       Lunch            1
# 5     U003   Breakfast            1
# 6     U004      Dinner            1
# 7     U004       Lunch            1
# 8     U005      Dinner            1
# 9     U005       Lunch            1
# 10    U006      Dinner            1
# 11    U007      Dinner            1
# 12    U008       Lunch            1

# %%
# Total Number of Orders per User
Total_orders_per_user = df_final.groupby('User ID').size().reset_index(name='Total Orders')
Total_orders_per_user
# Out:
#   User ID  Total Orders
# 0    U001             3
# 1    U002             3
# 2    U003             1
# 3    U004             2
# 4    U005             2
# 5    U006             1
# 6    U007             1
# 7    U008             1

# %%
#Rating Trends by Dish Type
rating_trends_by_dish = df_final.groupby('Dish Name_x').agg(
    Average_Rating=('Rating', 'mean'),
    Rating_Count=('Rating', 'count')
).reset_index().sort_values(by='Average_Rating', ascending=False)
rating_trends_by_dish
# Out:
#        Dish Name_x  Average_Rating  Rating_Count
# 1  Grilled Chicken        4.666667             3
# 4        Spaghetti        4.500000             4
# 0     Caesar Salad        4.000000             3
# 2          Oatmeal        4.000000             1
# 3         Pancakes        4.000000             2
# 5    Veggie Burger        4.000000             1

# %%
# Top 5 Dishes by Average Rating
plt.figure(figsize=(12, 6))
sns.barplot(data=rating_trends_by_dish.head(5), x='Dish Name_x', y='Average_Rating', palette='coolwarm')
plt.title('Top 5 Dishes by Average Rating')
plt.xlabel('Dish Name')
plt.ylabel('Average Rating')
plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Order Time Analysis
order_time_analysis = df_final.groupby('Time of Day').agg(
    Total_Orders=('Order ID', 'count'),
    Average_Rating=('Rating', 'mean')
).reset_index()
order_time_analysis
# Out:
#   Time of Day  Total_Orders  Average_Rating
# 0         Day             4        4.000000
# 1     Morning             3        4.000000
# 2       Night             7        4.571429
